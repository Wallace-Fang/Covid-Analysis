# %% [markdown]
# <a href="https://colab.research.google.com/github/Wallace-Fang/Covid-Analysis/blob/main/Youtube_API_Data_Mining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import requests
import pandas as pd
import time

# %%
API_KEY = "AIzaSyC_8f_eHAS4ieE_1okmunZcVCefKbNdF7M"

#Channel ID for youtube channel: LinusTechTips
CHANNEL_ID = "UCXuqSBlHAE6Xw-yeJA0Tunw"

# %%
def video_statistics(video_id):
  url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY
  stats_response = requests.get(url_video_stats).json()

  #acquire video's view, like, and comment count
  view_count = stats_response['items'][0]['statistics']['viewCount']
  like_count = stats_response['items'][0]['statistics']['likeCount']
  comment_count = stats_response['items'][0]['statistics']['commentCount']

  return view_count, like_count, comment_count

# %%
def get_videos(df):
  API_KEY = "AIzaSyC_8f_eHAS4ieE_1okmunZcVCefKbNdF7M"

  #Channel ID for youtube channel: LinusTechTips
  CHANNEL_ID = "UCXuqSBlHAE6Xw-yeJA0Tunw"

  #order results by date, maximum results of 10000, and in case multiple pages pageToken will access those pages
  pageToken= ""
  url = "https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=10000"+pageToken
  response = requests.get(url).json()
  time.sleep(1)

  for video in response['items']:

    #filters out none-video data and youtube short videos
    if video['id']['kind'] == "youtube#video" and video['snippet']['title'][-7:] != "#SHORTS":

      video_id = video['id']['videoId']

      #acquire video title
      video_title = video['snippet']['title']

      #acquire video update date
      upload_date = video['snippet']['publishTime']

      #Removes the timestamp and keeps only upload date
      upload_date = upload_date.split('T')[0] 
      
      view_count, like_count, comment_count = video_statistics(video_id)

      df = df.append({"video_id": video_id,
                  "video_title":video_title, 
                  "upload_date":upload_date, 
                  "view_count":view_count, 
                  "like_count":like_count, 
                  "comment_count":comment_count}, ignore_index=True)
  return df

# %%
df = pd.DataFrame(columns=["video_id", "video_title", "upload_date", "view_count", "like_count", "comment_count"])
df = get_videos(df)

# %%
df
# Out:
#        video_id  ... comment_count
# 0   EE4OCYOLjBc  ...          3627
# 1   c_Ab2F8UwvQ  ...          8087
# 2   UfcTm6cfkFQ  ...          2324
# 3   pqZFcrQTZ_E  ...          4815
# 4   rZ72mj1WgS0  ...          2416
# 5   zo_uoFI1WXM  ...          7598
# 6   ErtdxWaxKGA  ...          3103
# 7   qwLtPuBni0I  ...          3167
# 8   -znPFc-0VS8  ...          7389
# 9   A4HtrqVWH-k  ...          2069
# 10  4zXNMQCPv30  ...          2073
# 11  ImN-p_S9fMU  ...          3042
# 12  lOBaA9zg3XM  ...          3308
# 13  KYp6pEDm4E8  ...          3880
# 14  3YB3dkjn9XU  ...           969
# 15  OkCX8d8WSOg  ...          8192
# 16  psW70MxBC3k  ...           724
# 17  Nz9b0oJw69I  ...          9808
# 18  tN7Bv_adHs0  ...          2876
# 19  10ERchM9Q6g  ...          3407
# 20  JmWfngXmST4  ...           591
# 21  -wJOUAuKZm8  ...          2116
# 22  4nJUuNx800U  ...          2710
# 23  f76qQFjjHQ0  ...          1693
# 24  5JlTtMLYLUo  ...          5200
# 25  2HwGpoiePMg  ...          4496
# ...
